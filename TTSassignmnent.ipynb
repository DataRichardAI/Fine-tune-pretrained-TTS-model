# %% [markdown]
# # Install required packages
# This cell installs the necessary Python packages, pydub and ipython. pydub is used to manipulate audio files, while ipython is used to display the audio files in Jupyter Notebook or Google Colab.

# %%
# !pip install pydub
# !pip install ipython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython) (2.14.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython) (67.7.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (3.0.38)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython) (0.2.6)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2

# %% [markdown]
# ##In this code cell, various Python modules are imported that will be used throughout the script for different tasks.

# %%
import os
import random
import json
import shutil
import urllib.request
from glob import glob
import subprocess
from pydub import AudioSegment
from IPython.display import Audio

# %% [markdown]
# ## In this code cell, the dataset containing the "Jenie Angry" speech emotion audio files is downloaded and extracted:
#
# - The 'speaker_emotion_url' variable is assigned the URL of the dataset hosted on the OpenSLR website.
#
# - 'urllib.request.urlretrieve' is used to download the dataset file 'jenie_Angry.tar.gz' from the given URL.
#
# - The '!mkdir' command creates a new directory named 'jenie_angry_wav'. The exclamation mark (!) at the beginning of the command indicates that it's a shell command, not a Python command.
#
# - The !tar command is used to extract the contents of the downloaded jenie_Angry.tar.gz file to the jenie_angry_wav directory. The -xvf flags indicate that the tar file should be extracted (x), with verbose output (v) and that it's a file (f). The -C flag specifies the target directory for the extracted files.

# %%
#Download data and unzip files
speaker_emotion_url = "https://www.openslr.org/resources/115/jenie_Angry.tar.gz"
urllib.request.urlretrieve(speaker_emotion_url, "jenie_Angry.tar.gz")

# !mkdir jenie_angry_wav
# !tar -xvf jenie_Angry.tar.gz -C jenie_angry_wav
# Out:
# anger_1-28_0001.wav
# anger_1-28_0002.wav
# anger_1-28_0003.wav
# anger_1-28_0004.wav
# anger_1-28_0005.wav
# anger_1-28_0006.wav
# anger_1-28_0007.wav
# anger_1-28_0008.wav
# anger_1-28_0009.wav
# anger_1-28_0010.wav
# anger_1-28_0011.wav
# anger_1-28_0012.wav
# anger_1-28_0013.wav
# anger_1-28_0014.wav
# anger_1-28_0015.wav
# anger_1-28_0016.wav
# anger_1-28_0017.wav
# anger_1-28_0018.wav
# anger_1-28_0019.wav
# anger_1-28_0020.wav
# anger_1-28_0021.wav
# anger_1-28_0022.wav
# anger_1-28_0023.wav
# anger_1-28_0024.wav
# anger_1-28_0025.wav
# anger_1-28_0026.wav
# anger_1-28_0027.wav
# anger_1-28_0028.wav
# anger_113-140_0113.wav
# anger_113-140_0114.wav
# anger_113-140_0115.wav
# anger_113-140_0116.wav
# anger_113-140_0117.wav
# anger_113-140_0118.wav
# anger_113-140_0119.wav
# anger_113-140_0120.wav
# anger_113-140_0121.wav
# anger_113-140_0122.wav
# anger_113-140_0123.wav
# anger_113-140_0124.wav
# anger_113-140_0125.wav
# anger_113-140_0126.wav
# anger_113-140_0127.wav
# anger_113-140_0128.wav
# anger_113-140_0129.wav
# anger_113-140_0130.wav
# anger_113-140_0131.wav
# anger_113-140_0132.wav
# anger_113-140_0133.wav
# anger_113-140_0134.wav
# anger_113-140_0135.wav
# anger_113-140_0136.wav
# anger_113-140_0137.wav
# anger_113-140_0138.wav
# anger_113-140_0139.wav
# anger_113-140_0140.wav
# anger_57-84_0071.wav
# anger_57-84_0072.wav
# anger_57-84_0073.wav
# anger_57-84_0074.wav
# anger_57-84_0075.wav
# anger_57-84_0076.wav
# anger_57-84_0077.wav
# anger_57-84_0078.wav
# anger_57-84_0079.wav
# anger_57-84_0080.wav
# anger_57-84_0081.wav
# anger_57-84_0082.wav
# anger_57-84_0083.wav
# anger_57-84_0084.wav

# %% [markdown]
# ###In this code cell, the script downloads the transcript file for the CMU Arctic dataset using the urllib.request.urlretrieve() function. The transcript file contains the text corresponding to each audio file in the dataset.

# %%
#Download transcripts
transcript_url = "http://www.festvox.org/cmu_arctic/cmuarctic.data"
urllib.request.urlretrieve(transcript_url, "cmuarctic.data")
# Out:
# ('cmuarctic.data', <http.client.HTTPMessage at 0x7fa117a45840>)

# %% [markdown]
# ###In this code cell, the script preprocesses the audio data, creates metadata files for training and validation, and organizes the audio files into separate directories.

# %%
#Preprocess data and create metadata file
data_dir = "jenie_angry_wav"
wavs_dir = "ori_wavs"
transcript_file = "cmuarctic.data"

file_paths = sorted(glob(os.path.join(data_dir, "*.wav")))
random.shuffle(file_paths)
train_file_paths = file_paths[:15]  # Choose 15 random files
val_file_paths = file_paths[15:20]

train_metadata = []
val_metadata = []

with open(transcript_file, "r") as f:
    lines = f.readlines()
    transcripts = {line.split()[1]: " ".join(line.split()[2:-1]).strip('"') for line in lines}
os.makedirs(wavs_dir, exist_ok=True)

if os.path.exists(wavs_dir):
    shutil.rmtree(wavs_dir)

os.makedirs(wavs_dir, exist_ok=True)

for file_path in train_file_paths:
    file_id = os.path.basename(file_path).split("_")[-1].split(".")[0]
    transcript_key = f"arctic_a{file_id}"
    if transcript_key in transcripts:
        transcript = transcripts[transcript_key]
        new_file_path = os.path.join(wavs_dir, f"{file_id}.wav")
        os.rename(file_path, new_file_path)
        train_metadata.append((f"{file_id}.wav", transcript))

for file_path in val_file_paths:
    file_id = os.path.basename(file_path).split("_")[-1].split(".")[0]
    transcript_key = f"arctic_a{file_id}"
    if transcript_key in transcripts:
        transcript = transcripts[transcript_key]
        new_file_path = os.path.join(wavs_dir, f"{file_id}.wav")
        os.rename(file_path, new_file_path)
        val_metadata.append((f"{file_id}.wav", transcript))


with open("metadata.txt", "w") as f:
    for item in train_metadata:
        f.write(f"{item[0].strip('.wav')}|{item[1]}\n")
with open("metadata_val.txt", "w") as f:
    for item in val_metadata:
        f.write(f"{item[0].strip('.wav')}|{item[1]}\n")

# %% [markdown]
# ###In this code cell, the script resamples the audio files to a consistent sample rate.

# %%
resampled_wavs_dir = "/content/wavs"
os.makedirs(resampled_wavs_dir, exist_ok=True)

wav_files = glob(os.path.join(wavs_dir, "*.wav"))

for wav_file in wav_files:
    file_name = os.path.basename(wav_file)
    output_file_path = os.path.join(resampled_wavs_dir, file_name)

    command = f"ffmpeg -i {wav_file} -ar 22050 {output_file_path}"
    subprocess.run(command, shell=True, check=True)

# %% [markdown]
# #Display audio file and sample rate.

# %%
wavs_directory = "/content/wavs/"
first_audio_file = None

for file in os.listdir(wavs_directory):
    if file.endswith(".wav"):
        audio_file_path = os.path.join(wavs_directory, file)
        break
audio = AudioSegment.from_wav(audio_file_path)
sample_rate = audio.frame_rate

print(f"The sample rate of the audio file is {sample_rate} Hz")
# Out:
# The sample rate of the audio file is 22050 Hz

# %%
Audio(audio_file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #Clone and install TTS repository
# This cell clones the Coqui TTS repository, installs the TTS package, and lists the available pre-trained TTS models.

# %%
# %cd /content
# !git clone https://github.com/coqui-ai/TTS.git
# !pip install TTS
# !tts --list_models
# Out:
# /content
# Cloning into 'TTS'...
# remote: Enumerating objects: 29730, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 29730 (delta 74), reused 86 (delta 58), pack-reused 29607
# Receiving objects: 100% (29730/29730), 159.14 MiB | 33.43 MiB/s, done.
# Resolving deltas: 100% (21554/21554), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting TTS
#   Downloading TTS-0.13.3-cp310-cp310-manylinux1_x86_64.whl (655 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 655.3/655.3 kB 12.1 MB/s eta 0:00:00
# Collecting bnunicodenormalizer==0.1.1
#   Downloading bnunicodenormalizer-0.1.1.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from TTS) (2.2.4)
# Collecting g2pkk>=0.1.1
#   Downloading g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Collecting pypinyin
#   Downloading pypinyin-0.48.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 51.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2021.04.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (2023.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from TTS) (6.0)
# Collecting trainer==0.0.20
#   Downloading trainer-0.0.20-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from TTS) (1.10.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from TTS) (0.12.1)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from TTS) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from TTS) (4.65.0)
# Collecting bangla==0.0.2
#   Downloading bangla-0.0.2-py2.py3-none-any.whl (6.2 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from TTS) (3.8.1)
# Requirement already satisfied: librosa==0.10.0.* in /usr/local/lib/python3.10/dist-packages (from TTS) (0.10.0.post2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from TTS) (23.1)
# Collecting cython==0.29.28
#   Downloading Cython-0.29.28-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 65.9 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.3 MB/s eta 0:00:00
# Collecting bnnumerizer
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from TTS) (3.7.1)
# Collecting coqpit>=0.0.16
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting unidic-lite==1.0.8
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting anyascii
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 27.8 MB/s eta 0:00:00
# Requirement already satisfied: numba==0.56.4 in /usr/local/lib/python3.10/dist-packages (from TTS) (0.56.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from TTS) (1.5.3)
# Collecting jamo
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from TTS) (1.22.4)
# Collecting inflect==5.6.0
#   Downloading inflect-5.6.0-py3-none-any.whl (33 kB)
# Collecting gruut[de]==2.2.3
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting umap-learn==0.5.1
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pysbd
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from TTS) (0.42.1)
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.1/581.1 kB 51.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from TTS) (2.0.0+cu118)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de]==2.2.3->TTS) (2.12.1)
# Collecting dateparser~=1.1.0
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 30.6 MB/s eta 0:00:00
# Collecting gruut-ipa<1.0,>=0.12.0
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0
#   Downloading gruut_lang_en-2.0.0.tar.gz (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Collecting networkx<3.0.0,>=2.5.0
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 82.3 MB/s eta 0:00:00
# Collecting num2words<1.0.0,>=0.5.10
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 14.4 MB/s eta 0:00:00
# Collecting python-crfsuite~=0.9.7
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 63.0 MB/s eta 0:00:00
# Collecting gruut_lang_de~=2.0.0
#   Downloading gruut_lang_de-2.0.0.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 69.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (1.2.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (0.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (4.4.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (4.5.0)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (1.6.0)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (1.0.5)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (1.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.10.0.*->TTS) (3.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba==0.56.4->TTS) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba==0.56.4->TTS) (0.39.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from trainer==0.0.20->TTS) (5.9.5)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 61.7 MB/s eta 0:00:00
# Collecting tensorboardX
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.4 MB/s eta 0:00:00
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->TTS) (1.15.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->TTS) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->TTS) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->TTS) (2.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->TTS) (3.12.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->TTS) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7->TTS) (3.25.2)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->TTS) (23.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->TTS) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->TTS) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->TTS) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->TTS) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->TTS) (0.11.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->TTS) (2022.10.31)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->TTS) (2022.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->TTS) (2.21)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.0->gruut[de]==2.2.3->TTS) (4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->TTS) (2.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from jsonlines~=1.2.0->gruut[de]==2.2.3->TTS) (1.16.0)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa==0.10.0.*->TTS) (2.27.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa==0.10.0.*->TTS) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa==0.10.0.*->TTS) (3.1.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp->TTS) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->TTS) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.*->TTS) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.*->TTS) (2022.12.7)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal->dateparser~=1.1.0->gruut[de]==2.2.3->TTS) (0.1.0.post0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal->dateparser~=1.1.0->gruut[de]==2.2.3->TTS) (2023.3)
# Building wheels for collected packages: bnunicodenormalizer, umap-learn, unidic-lite, bnnumerizer, gruut-ipa, gruut_lang_de, gruut_lang_en, pynndescent, gruut, docopt
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.1-py3-none-any.whl size=21912 sha256=8b33e5aef04b7950149d5eef0b142e95ac2cdd21b5f6d544cd39d261e83909a1
#   Stored in directory: /root/.cache/pip/wheels/b4/f6/01/9e68ecec7c7ea85fc9431cfac42eba1c5a5f6debe5070de5c7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76564 sha256=5d3463b0e1d03161ea51d32698f224ad4ee94ad706583be7ac7cf0da65113a92
#   Stored in directory: /root/.cache/pip/wheels/69/21/8e/802cb9c4c606a67139f538cb17bf3bf1b98b739a7900469953
#   Building wheel for unidic-lite (setup.py) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658834 sha256=51c4c157e5182db35e6e646e2be846110ac7f43c433336b29a5da844aa3bfe4a
#   Stored in directory: /root/.cache/pip/wheels/89/e8/68/f9ac36b8cc6c8b3c96888cd57434abed96595d444f42243853
#   Building wheel for bnnumerizer (setup.py) ... done
#   Created wheel for bnnumerizer: filename=bnnumerizer-0.0.2-py3-none-any.whl size=5276 sha256=1a70b6aeb468099694e110a9f3f9a37a25e53fdeecdb7518e6a24b4628d1c313
#   Stored in directory: /root/.cache/pip/wheels/59/6b/e8/223172e7d5c9f72df3ea1a0d9258f3a8ab5b28e827728edef5
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104891 sha256=98482ed6cf81561ace241287c0ebe1dcce47e687b151abfa217d2846d48a0c4b
#   Stored in directory: /root/.cache/pip/wheels/7b/18/49/e4f500ecdf0babe757953f844e4d7cd1ea81c5503c09bfe984
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.0-py3-none-any.whl size=18498199 sha256=f450588a1996c762fe4715712ef32014d388847c8c0e89743d3bcfce2bd03ff6
#   Stored in directory: /root/.cache/pip/wheels/95/9a/05/cfce98f0c41a1a540f15708c4a02df190b82d84cf91ef6bc7f
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.0-py3-none-any.whl size=15297195 sha256=81654f48cbcf17974ce9784b776ace161b918ee3bfc1c678290adfff7b73a010
#   Stored in directory: /root/.cache/pip/wheels/10/9c/fb/77c655a9fbd78cdb9935d0ab65d80ddd0a3bcf7dbe18261650
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=0c1d03440b691633cccb88ee2fd60bbcfe2187d449970b2603c479db1fee8a51
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-2.2.3-py3-none-any.whl size=75817 sha256=9a22abc13e090793c90497c00e3bb6bd04dcc5fe6cfce026741596d70275e5ae
#   Stored in directory: /root/.cache/pip/wheels/fc/57/a8/f9de532daf5214f53644f20f3a9e6f69269453c87df9c0a817
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=50c359c5cd3b96f5b2df941ddf2fc734bf685c6d6f6606da4ffbfce41447a147
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built bnunicodenormalizer umap-learn unidic-lite bnnumerizer gruut-ipa gruut_lang_de gruut_lang_en pynndescent gruut docopt
# Installing collected packages: unidic-lite, python-crfsuite, mecab-python3, jamo, gruut_lang_en, gruut_lang_de, docopt, bnunicodenormalizer, bnnumerizer, bangla, pysbd, pypinyin, protobuf, num2words, networkx, multidict, jsonlines, inflect, gruut-ipa, frozenlist, cython, coqpit, async-timeout, anyascii, yarl, tensorboardX, g2pkk, aiosignal, pynndescent, dateparser, aiohttp, umap-learn, gruut, trainer, TTS
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: inflect
#     Found existing installation: inflect 6.0.4
#     Uninstalling inflect-6.0.4:
#       Successfully uninstalled inflect-6.0.4
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.34
#     Uninstalling Cython-0.29.34:
#       Successfully uninstalled Cython-0.29.34
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed TTS-0.13.3 aiohttp-3.8.4 aiosignal-1.3.1 anyascii-0.3.2 async-timeout-4.0.2 bangla-0.0.2 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.1 coqpit-0.0.17 cython-0.29.28 dateparser-1.1.8 docopt-0.6.2 frozenlist-1.3.3 g2pkk-0.1.2 gruut-2.2.3 gruut-ipa-0.13.0 gruut_lang_de-2.0.0 gruut_lang_en-2.0.0 inflect-5.6.0 jamo-0.4.1 jsonlines-1.2.0 mecab-python3-1.0.5 multidict-6.0.4 networkx-2.8.8 num2words-0.5.12 protobuf-3.19.6 pynndescent-0.5.10 pypinyin-0.48.0 pysbd-0.3.4 python-crfsuite-0.9.9 tensorboardX-2.6 trainer-0.0.20 umap-learn-0.5.1 unidic-lite-1.0.8 yarl-1.9.2
# No API token found for 🐸Coqui Studio voices - https://coqui.ai
# Visit 🔗https://app.coqui.ai/account to get one.
# Set it as an environment variable `export COQUI_STUDIO_TOKEN=<token>`
#
#  Name format: type/language/dataset/model
#  1: tts_models/multilingual/multi-dataset/your_tts
#  2: tts_models/bg/cv/vits
#  3: tts_models/cs/cv/vits
#  4: tts_models/da/cv/vits
#  5: tts_models/et/cv/vits
#  6: tts_models/ga/cv/vits
#  7: tts_models/en/ek1/tacotron2
#  8: tts_models/en/ljspeech/tacotron2-DDC
#  9: tts_models/en/ljspeech/tacotron2-DDC_ph
#  10: tts_models/en/ljspeech/glow-tts
#  11: tts_models/en/ljspeech/speedy-speech
#  12: tts_models/en/ljspeech/tacotron2-DCA
#  13: tts_models/en/ljspeech/vits
#  14: tts_models/en/ljspeech/vits--neon
#  15: tts_models/en/ljspeech/fast_pitch
#  16: tts_models/en/ljspeech/overflow
#  17: tts_models/en/ljspeech/neural_hmm
#  18: tts_models/en/vctk/vits
#  19: tts_models/en/vctk/fast_pitch
#  20: tts_models/en/sam/tacotron-DDC
#  21: tts_models/en/blizzard2013/capacitron-t2-c50
#  22: tts_models/en/blizzard2013/capacitron-t2-c150_v2
#  23: tts_models/es/mai/tacotron2-DDC
#  24: tts_models/es/css10/vits
#  25: tts_models/fr/mai/tacotron2-DDC
#  26: tts_models/fr/css10/vits
#  27: tts_models/uk/mai/glow-tts
#  28: tts_models/uk/mai/vits
#  29: tts_models/zh-CN/baker/tacotron2-DDC-GST
#  30: tts_models/nl/mai/tacotron2-DDC
#  31: tts_models/nl/css10/vits
#  32: tts_models/de/thorsten/tacotron2-DCA
#  33: tts_models/de/thorsten/vits
#  34: tts_models/de/thorsten/tacotron2-DDC
#  35: tts_models/de/css10/vits-neon
#  36: tts_models/ja/kokoro/tacotron2-DDC
#  37: tts_models/tr/common-voice/glow-tts
#  38: tts_models/it/mai_female/glow-tts
#  39: tts_models/it/mai_female/vits
#  40: tts_models/it/mai_male/glow-tts
#  41: tts_models/it/mai_male/vits
#  42: tts_models/ewe/openbible/vits
#  43: tts_models/hau/openbible/vits
#  44: tts_models/lin/openbible/vits
#  45: tts_models/tw_akuapem/openbible/vits
#  46: tts_models/tw_asante/openbible/vits
#  47: tts_models/yor/openbible/vits
#  48: tts_models/hu/css10/vits
#  49: tts_models/el/cv/vits
#  50: tts_models/fi/css10/vits
#  51: tts_models/hr/cv/vits
#  52: tts_models/lt/cv/vits
#  53: tts_models/lv/cv/vits
#  54: tts_models/mt/cv/vits
#  55: tts_models/pl/mai_female/vits
#  56: tts_models/pt/cv/vits
#  57: tts_models/ro/cv/vits
#  58: tts_models/sk/cv/vits
#  59: tts_models/sl/cv/vits
#  60: tts_models/sv/cv/vits
#  61: tts_models/ca/custom/vits
#  62: tts_models/fa/custom/glow-tts
#  63: tts_models/bn/custom/vits-male
#  64: tts_models/bn/custom/vits-female
#  Name format: type/language/dataset/model
#  1: vocoder_models/universal/libri-tts/wavegrad
#  2: vocoder_models/universal/libri-tts/fullband-melgan
#  3: vocoder_models/en/ek1/wavegrad
#  4: vocoder_models/en/ljspeech/multiband-melgan
#  5: vocoder_models/en/ljspeech/hifigan_v2
#  6: vocoder_models/en/ljspeech/univnet
#  7: vocoder_models/en/blizzard2013/hifigan_v2
#  8: vocoder_models/en/vctk/hifigan_v2
#  9: vocoder_models/en/sam/hifigan_v2
#  10: vocoder_models/nl/mai/parallel-wavegan
#  11: vocoder_models/de/thorsten/wavegrad
#  12: vocoder_models/de/thorsten/fullband-melgan
#  13: vocoder_models/de/thorsten/hifigan_v1
#  14: vocoder_models/ja/kokoro/hifigan_v1
#  15: vocoder_models/uk/mai/multiband-melgan
#  16: vocoder_models/tr/common-voice/hifigan
#  Name format: type/language/dataset/model
#  1: voice_conversion_models/multilingual/vctk/freevc24

# %% [markdown]
# # Generate audio using pre-trained model
# This cell generates an audio file using a pre-trained Tacotron2-DDC model from Coqui and plays the synthesized audio.

# %%
# !tts --model_name tts_models/en/ljspeech/tacotron2-DDC --out_path /content/tacotron2.wav --text "What were you doing!! I told you to come fast."
# Out:
#  > Downloading model to /root/.local/share/tts/tts_models--en--ljspeech--tacotron2-DDC
# 100% 113M/113M [00:01<00:00, 75.1MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Downloading model to /root/.local/share/tts/vocoder_models--en--ljspeech--hifigan_v2
# 100% 3.80M/3.80M [00:00<00:00, 45.2MiB/s]
#  > Model's license - apache 2.0
#  > Check https://choosealicense.com/licenses/apache-2.0/ for more info.
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Model's reduction rate `r` is set to: 1
#  > Vocoder Model: hifigan
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: hifigan_generator
#  > Discriminator Model: hifigan_discriminator
# Removing weight norm...
#  > Text: What were you doing!! I told you to come fast.
#  > Text splitted to sentences.
# ['What were you doing!!', 'I told you to come fast.']
#  > Processing time: 2.1267313957214355
#  > Real-time factor: 0.511501170109704
#  > Saving output to /content/tacotron2.wav

# %% [markdown]
# ##In this code cell, the script creates a directory for storing pretrained models and moves the downloaded Tacotron2-DDC model into that directory:

# %%
# !mkdir -p /content/pretrained_models/
# !mv /root/.local/share/tts/tts_models--en--ljspeech--tacotron2-DDC /content/pretrained_models/

# %%
Audio("/content/tacotron2.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #Fine-tune the pre-trained model
# This cell fine-tunes the pre-trained Tacotron2-DDC model using the prepared dataset.
# #Make these changes in the config.json file present in the path as below (--config_path)
#
#
# - "lr" = 0.00001
# - "epochs" = 200
# - "warmup_steps" = 10
# - "output_path" = "/content/fine_tune/"
# - "phoneme_cache_path" = "/content/phoneme_cache/"
# - "datasets" = [
#     {
#         "name": "fine_tune_anie_angry",
#         "path": "/content/",
#         "meta_file_train": "metadata.txt",
#         "meta_file_val": None,
#         "formatter": "thorsten",
#         "unused_speakers": None,
#         "meta_file_attn_mask": "",
#     }

# %%
# !CUDA_VISIBLE_DEVICES="0" python /content/TTS/TTS/bin/train_tts.py \
    --config_path  /content/pretrained_models/tts_models--en--ljspeech--tacotron2-DDC/config.json \
    --restore_path  /content/pretrained_models/tts_models--en--ljspeech--tacotron2-DDC/model_file.pth
# Out:
# Streaming output truncated to the last 5000 lines.
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:45:42)
#
#  > CHECKPOINT : /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/checkpoint_278120.pth
# warning: audio amplitude out of range, auto clipped.
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11790 (-0.00390)
#      | > avg_decoder_loss: 2.75440 (+0.19647)
#      | > avg_postnet_loss: 2.49472 (+0.15846)
#      | > avg_stopnet_loss: 0.12612 (-0.00482)
#      | > avg_ga_loss: 0.00533 (-0.00016)
#      | > avg_loss: 5.40190 (+0.34930)
#      | > avg_align_error: 0.72999 (-0.00835)
#
#
#  > EPOCH: 120/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:46:13)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12944 (+0.01154)
#      | > avg_decoder_loss: 2.53009 (-0.22430)
#      | > avg_postnet_loss: 2.30261 (-0.19211)
#      | > avg_stopnet_loss: 0.10712 (-0.01899)
#      | > avg_ga_loss: 0.00558 (+0.00025)
#      | > avg_loss: 4.96774 (-0.43416)
#      | > avg_align_error: 0.72637 (-0.00362)
#
#
#  > EPOCH: 121/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:46:38)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12248 (-0.00695)
#      | > avg_decoder_loss: 2.63812 (+0.10802)
#      | > avg_postnet_loss: 2.40227 (+0.09966)
#      | > avg_stopnet_loss: 0.15541 (+0.04828)
#      | > avg_ga_loss: 0.00535 (-0.00024)
#      | > avg_loss: 5.22252 (+0.25478)
#      | > avg_align_error: 0.70908 (-0.01730)
#
#
#  > EPOCH: 122/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:47:03)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.22569 (+0.10321)
#      | > avg_decoder_loss: 2.59808 (-0.04004)
#      | > avg_postnet_loss: 2.36948 (-0.03278)
#      | > avg_stopnet_loss: 0.12233 (-0.03307)
#      | > avg_ga_loss: 0.00567 (+0.00033)
#      | > avg_loss: 5.11826 (-0.10426)
#      | > avg_align_error: 0.73578 (+0.02670)
#
#
#  > EPOCH: 123/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:47:28)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12170 (-0.10399)
#      | > avg_decoder_loss: 2.49797 (-0.10011)
#      | > avg_postnet_loss: 2.27771 (-0.09178)
#      | > avg_stopnet_loss: 0.13469 (+0.01236)
#      | > avg_ga_loss: 0.00552 (-0.00015)
#      | > avg_loss: 4.93797 (-0.18029)
#      | > avg_align_error: 0.75051 (+0.01473)
#
#
#  > EPOCH: 124/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:47:53)
#
#    --> STEP: 0/1 -- GLOBAL_STEP: 278125
#      | > decoder_loss: 3.21037  (3.21037)
#      | > postnet_loss: 2.98706  (2.98706)
#      | > stopnet_loss: 0.14769  (0.14769)
#      | > ga_loss: 0.00343  (0.00343)
#      | > loss: 6.36226  (6.36226)
#      | > align_error: 0.69100  (0.69100)
#      | > grad_norm: 136.67764  (136.67764)
#      | > current_lr: 0.00000
#      | > step_time: 2.41070  (2.41074)
#      | > loader_time: 0.64190  (0.64195)
#
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12784 (+0.00614)
#      | > avg_decoder_loss: 2.69049 (+0.19252)
#      | > avg_postnet_loss: 2.43866 (+0.16096)
#      | > avg_stopnet_loss: 0.12736 (-0.00733)
#      | > avg_ga_loss: 0.00551 (-0.00001)
#      | > avg_loss: 5.28408 (+0.34611)
#      | > avg_align_error: 0.75215 (+0.00164)
#
#
#  > EPOCH: 125/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:48:19)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12011 (-0.00773)
#      | > avg_decoder_loss: 2.61604 (-0.07446)
#      | > avg_postnet_loss: 2.37542 (-0.06324)
#      | > avg_stopnet_loss: 0.13561 (+0.00825)
#      | > avg_ga_loss: 0.00562 (+0.00011)
#      | > avg_loss: 5.15519 (-0.12889)
#      | > avg_align_error: 0.73681 (-0.01534)
#
#
#  > EPOCH: 126/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:48:44)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.22133 (+0.10121)
#      | > avg_decoder_loss: 2.65366 (+0.03762)
#      | > avg_postnet_loss: 2.42269 (+0.04727)
#      | > avg_stopnet_loss: 0.12734 (-0.00827)
#      | > avg_ga_loss: 0.00536 (-0.00027)
#      | > avg_loss: 5.23047 (+0.07528)
#      | > avg_align_error: 0.71294 (-0.02387)
#
#
#  > EPOCH: 127/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:49:09)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11941 (-0.10191)
#      | > avg_decoder_loss: 2.51669 (-0.13697)
#      | > avg_postnet_loss: 2.28916 (-0.13353)
#      | > avg_stopnet_loss: 0.11564 (-0.01170)
#      | > avg_ga_loss: 0.00539 (+0.00003)
#      | > avg_loss: 4.94844 (-0.28203)
#      | > avg_align_error: 0.73985 (+0.02691)
#
#
#  > EPOCH: 128/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:49:35)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12828 (+0.00887)
#      | > avg_decoder_loss: 2.66117 (+0.14448)
#      | > avg_postnet_loss: 2.41610 (+0.12694)
#      | > avg_stopnet_loss: 0.13049 (+0.01485)
#      | > avg_ga_loss: 0.00538 (-0.00000)
#      | > avg_loss: 5.23469 (+0.28625)
#      | > avg_align_error: 0.73889 (-0.00096)
#
#
#  > EPOCH: 129/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:49:59)
#
#  > CHECKPOINT : /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/checkpoint_278130.pth
# warning: audio amplitude out of range, auto clipped.
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11372 (-0.01456)
#      | > avg_decoder_loss: 2.64533 (-0.01584)
#      | > avg_postnet_loss: 2.40378 (-0.01233)
#      | > avg_stopnet_loss: 0.14502 (+0.01453)
#      | > avg_ga_loss: 0.00501 (-0.00038)
#      | > avg_loss: 5.21917 (-0.01552)
#      | > avg_align_error: 0.73215 (-0.00674)
#
#
#  > EPOCH: 130/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:50:31)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11717 (+0.00345)
#      | > avg_decoder_loss: 2.61679 (-0.02854)
#      | > avg_postnet_loss: 2.37978 (-0.02400)
#      | > avg_stopnet_loss: 0.12239 (-0.02263)
#      | > avg_ga_loss: 0.00536 (+0.00035)
#      | > avg_loss: 5.14577 (-0.07340)
#      | > avg_align_error: 0.74374 (+0.01159)
#
#
#  > EPOCH: 131/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:50:55)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.22338 (+0.10621)
#      | > avg_decoder_loss: 2.69907 (+0.08228)
#      | > avg_postnet_loss: 2.45785 (+0.07806)
#      | > avg_stopnet_loss: 0.14245 (+0.02006)
#      | > avg_ga_loss: 0.00543 (+0.00007)
#      | > avg_loss: 5.32653 (+0.18076)
#      | > avg_align_error: 0.70762 (-0.03612)
#
#
#  > EPOCH: 132/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:51:20)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12602 (-0.09736)
#      | > avg_decoder_loss: 2.61477 (-0.08430)
#      | > avg_postnet_loss: 2.38087 (-0.07698)
#      | > avg_stopnet_loss: 0.11021 (-0.03224)
#      | > avg_ga_loss: 0.00572 (+0.00029)
#      | > avg_loss: 5.13445 (-0.19208)
#      | > avg_align_error: 0.74632 (+0.03870)
#
#
#  > EPOCH: 133/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:51:47)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11591 (-0.01011)
#      | > avg_decoder_loss: 2.65004 (+0.03527)
#      | > avg_postnet_loss: 2.40575 (+0.02488)
#      | > avg_stopnet_loss: 0.14327 (+0.03306)
#      | > avg_ga_loss: 0.00563 (-0.00009)
#      | > avg_loss: 5.22720 (+0.09275)
#      | > avg_align_error: 0.71711 (-0.02921)
#
#
#  > EPOCH: 134/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:52:17)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12659 (+0.01067)
#      | > avg_decoder_loss: 2.50591 (-0.14413)
#      | > avg_postnet_loss: 2.28568 (-0.12006)
#      | > avg_stopnet_loss: 0.13500 (-0.00827)
#      | > avg_ga_loss: 0.00502 (-0.00061)
#      | > avg_loss: 4.95170 (-0.27550)
#      | > avg_align_error: 0.74979 (+0.03268)
#
#
#  > EPOCH: 135/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:52:43)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12082 (-0.00577)
#      | > avg_decoder_loss: 2.64584 (+0.13993)
#      | > avg_postnet_loss: 2.41331 (+0.12763)
#      | > avg_stopnet_loss: 0.14092 (+0.00592)
#      | > avg_ga_loss: 0.00531 (+0.00029)
#      | > avg_loss: 5.22664 (+0.27494)
#      | > avg_align_error: 0.72767 (-0.02212)
#
#
#  > EPOCH: 136/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:53:07)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12199 (+0.00117)
#      | > avg_decoder_loss: 2.49754 (-0.14830)
#      | > avg_postnet_loss: 2.27453 (-0.13879)
#      | > avg_stopnet_loss: 0.14709 (+0.00617)
#      | > avg_ga_loss: 0.00554 (+0.00022)
#      | > avg_loss: 4.94684 (-0.27980)
#      | > avg_align_error: 0.71974 (-0.00793)
#
#
#  > EPOCH: 137/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:53:32)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.22332 (+0.10133)
#      | > avg_decoder_loss: 2.32168 (-0.17586)
#      | > avg_postnet_loss: 2.11951 (-0.15502)
#      | > avg_stopnet_loss: 0.10897 (-0.03812)
#      | > avg_ga_loss: 0.00530 (-0.00024)
#      | > avg_loss: 4.57667 (-0.37017)
#      | > avg_align_error: 0.74019 (+0.02045)
#
#
#  > EPOCH: 138/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:53:57)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11680 (-0.10652)
#      | > avg_decoder_loss: 2.61625 (+0.29457)
#      | > avg_postnet_loss: 2.37986 (+0.26035)
#      | > avg_stopnet_loss: 0.12034 (+0.01137)
#      | > avg_ga_loss: 0.00553 (+0.00023)
#      | > avg_loss: 5.14410 (+0.56743)
#      | > avg_align_error: 0.72984 (-0.01034)
#
#
#  > EPOCH: 139/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:54:23)
#
#  > CHECKPOINT : /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/checkpoint_278140.pth
# warning: audio amplitude out of range, auto clipped.
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11802 (+0.00122)
#      | > avg_decoder_loss: 2.63238 (+0.01613)
#      | > avg_postnet_loss: 2.40461 (+0.02474)
#      | > avg_stopnet_loss: 0.12645 (+0.00611)
#      | > avg_ga_loss: 0.00536 (-0.00017)
#      | > avg_loss: 5.19022 (+0.04612)
#      | > avg_align_error: 0.74374 (+0.01389)
#
#
#  > EPOCH: 140/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:54:54)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11854 (+0.00052)
#      | > avg_decoder_loss: 2.46618 (-0.16621)
#      | > avg_postnet_loss: 2.25914 (-0.14547)
#      | > avg_stopnet_loss: 0.11160 (-0.01485)
#      | > avg_ga_loss: 0.00544 (+0.00008)
#      | > avg_loss: 4.86412 (-0.32610)
#      | > avg_align_error: 0.73170 (-0.01203)
#
#
#  > EPOCH: 141/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:55:20)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11882 (+0.00028)
#      | > avg_decoder_loss: 2.56863 (+0.10245)
#      | > avg_postnet_loss: 2.33760 (+0.07846)
#      | > avg_stopnet_loss: 0.12611 (+0.01451)
#      | > avg_ga_loss: 0.00534 (-0.00010)
#      | > avg_loss: 5.05906 (+0.19494)
#      | > avg_align_error: 0.74460 (+0.01289)
#
#
#  > EPOCH: 142/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:55:44)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.23494 (+0.11611)
#      | > avg_decoder_loss: 2.39352 (-0.17511)
#      | > avg_postnet_loss: 2.17648 (-0.16112)
#      | > avg_stopnet_loss: 0.14264 (+0.01653)
#      | > avg_ga_loss: 0.00518 (-0.00017)
#      | > avg_loss: 4.73853 (-0.32053)
#      | > avg_align_error: 0.73366 (-0.01094)
#
#
#  > EPOCH: 143/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:56:21)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.13484 (-0.10010)
#      | > avg_decoder_loss: 2.53046 (+0.13694)
#      | > avg_postnet_loss: 2.30123 (+0.12475)
#      | > avg_stopnet_loss: 0.14187 (-0.00077)
#      | > avg_ga_loss: 0.00549 (+0.00032)
#      | > avg_loss: 5.00103 (+0.26250)
#      | > avg_align_error: 0.72091 (-0.01275)
#
#
#  > EPOCH: 144/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:56:47)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12561 (-0.00923)
#      | > avg_decoder_loss: 2.44762 (-0.08285)
#      | > avg_postnet_loss: 2.22632 (-0.07491)
#      | > avg_stopnet_loss: 0.12166 (-0.02021)
#      | > avg_ga_loss: 0.00526 (-0.00023)
#      | > avg_loss: 4.82191 (-0.17912)
#      | > avg_align_error: 0.73076 (+0.00985)
#
#
#  > EPOCH: 145/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:57:11)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.28518 (+0.15957)
#      | > avg_decoder_loss: 2.40249 (-0.04513)
#      | > avg_postnet_loss: 2.18353 (-0.04280)
#      | > avg_stopnet_loss: 0.11774 (-0.00392)
#      | > avg_ga_loss: 0.00554 (+0.00028)
#      | > avg_loss: 4.73145 (-0.09046)
#      | > avg_align_error: 0.72684 (-0.00392)
#
#
#  > EPOCH: 146/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:57:37)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12311 (-0.16207)
#      | > avg_decoder_loss: 2.59969 (+0.19720)
#      | > avg_postnet_loss: 2.36182 (+0.17829)
#      | > avg_stopnet_loss: 0.14834 (+0.03060)
#      | > avg_ga_loss: 0.00544 (-0.00010)
#      | > avg_loss: 5.13705 (+0.40559)
#      | > avg_align_error: 0.74228 (+0.01544)
#
#
#  > EPOCH: 147/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 18:58:02)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# ...
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10625 (+0.00263)
#      | > avg_decoder_loss: 2.59922 (+0.39484)
#      | > avg_postnet_loss: 2.35250 (+0.34290)
#      | > avg_stopnet_loss: 0.10808 (-0.00859)
#      | > avg_ga_loss: 0.00548 (+0.00009)
#      | > avg_loss: 5.08720 (+0.72962)
#      | > avg_align_error: 0.73437 (-0.01479)
#
#
#  > EPOCH: 191/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:16:49)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.11828 (+0.01203)
#      | > avg_decoder_loss: 2.50563 (-0.09359)
#      | > avg_postnet_loss: 2.27051 (-0.08199)
#      | > avg_stopnet_loss: 0.14369 (+0.03560)
#      | > avg_ga_loss: 0.00548 (-0.00000)
#      | > avg_loss: 4.94721 (-0.13999)
#      | > avg_align_error: 0.72914 (-0.00523)
#
#
#  > EPOCH: 192/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:17:12)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10555 (-0.01273)
#      | > avg_decoder_loss: 2.52073 (+0.01510)
#      | > avg_postnet_loss: 2.28260 (+0.01209)
#      | > avg_stopnet_loss: 0.13352 (-0.01016)
#      | > avg_ga_loss: 0.00565 (+0.00018)
#      | > avg_loss: 4.96513 (+0.01792)
#      | > avg_align_error: 0.72460 (-0.00454)
#
#
#  > EPOCH: 193/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:17:34)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.20542 (+0.09987)
#      | > avg_decoder_loss: 2.39858 (-0.12215)
#      | > avg_postnet_loss: 2.17404 (-0.10856)
#      | > avg_stopnet_loss: 0.12637 (-0.00716)
#      | > avg_ga_loss: 0.00509 (-0.00057)
#      | > avg_loss: 4.72442 (-0.24071)
#      | > avg_align_error: 0.72732 (+0.00273)
#
#
#  > EPOCH: 194/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:17:56)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10983 (-0.09559)
#      | > avg_decoder_loss: 2.38531 (-0.01327)
#      | > avg_postnet_loss: 2.15982 (-0.01422)
#      | > avg_stopnet_loss: 0.12860 (+0.00223)
#      | > avg_ga_loss: 0.00532 (+0.00023)
#      | > avg_loss: 4.70033 (-0.02409)
#      | > avg_align_error: 0.75609 (+0.02877)
#
#
#  > EPOCH: 195/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:18:17)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.14135 (+0.03153)
#      | > avg_decoder_loss: 2.32470 (-0.06061)
#      | > avg_postnet_loss: 2.11656 (-0.04326)
#      | > avg_stopnet_loss: 0.14660 (+0.01800)
#      | > avg_ga_loss: 0.00471 (-0.00061)
#      | > avg_loss: 4.61140 (-0.08894)
#      | > avg_align_error: 0.72233 (-0.03376)
#
#
#  > EPOCH: 196/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:18:39)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10343 (-0.03792)
#      | > avg_decoder_loss: 2.29112 (-0.03358)
#      | > avg_postnet_loss: 2.08526 (-0.03130)
#      | > avg_stopnet_loss: 0.10807 (-0.03853)
#      | > avg_ga_loss: 0.00547 (+0.00077)
#      | > avg_loss: 4.51182 (-0.09958)
#      | > avg_align_error: 0.72955 (+0.00722)
#
#
#  > EPOCH: 197/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:19:01)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10216 (-0.00128)
#      | > avg_decoder_loss: 2.48174 (+0.19062)
#      | > avg_postnet_loss: 2.25215 (+0.16690)
#      | > avg_stopnet_loss: 0.13319 (+0.02511)
#      | > avg_ga_loss: 0.00524 (-0.00024)
#      | > avg_loss: 4.89327 (+0.38145)
#      | > avg_align_error: 0.74246 (+0.01292)
#
#
#  > EPOCH: 198/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:19:23)
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10529 (+0.00313)
#      | > avg_decoder_loss: 2.51716 (+0.03543)
#      | > avg_postnet_loss: 2.27875 (+0.02660)
#      | > avg_stopnet_loss: 0.12550 (-0.00768)
#      | > avg_ga_loss: 0.00509 (-0.00015)
#      | > avg_loss: 4.94686 (+0.05359)
#      | > avg_align_error: 0.74393 (+0.00147)
#
#
#  > EPOCH: 199/200
#  --> /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 15
#  | > Preprocessing samples
#  | > Max text length: 73
#  | > Min text length: 21
#  | > Avg text length: 53.2
#  |
#  | > Max audio length: 162979.0
#  | > Min audio length: 70513.0
#  | > Avg audio length: 121271.33333333333
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 128.
#
#  > TRAINING (2023-05-06 19:19:46)
#
#    --> STEP: 0/1 -- GLOBAL_STEP: 278200
#      | > decoder_loss: 2.82987  (2.82987)
#      | > postnet_loss: 2.61855  (2.61855)
#      | > stopnet_loss: 0.16579  (0.16579)
#      | > ga_loss: 0.00367  (0.00367)
#      | > loss: 5.63256  (5.63256)
#      | > align_error: 0.69564  (0.69564)
#      | > grad_norm: 121.20717  (121.20717)
#      | > current_lr: 0.00000
#      | > step_time: 2.35050  (2.35055)
#      | > loader_time: 0.80670  (0.80671)
#
#
#  > CHECKPOINT : /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/checkpoint_278200.pth
# warning: audio amplitude out of range, auto clipped.
#
#
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: False
# | > Number of instances : 5
#  | > Preprocessing samples
#  | > Max text length: 64
#  | > Min text length: 33
#  | > Avg text length: 53.6
#  |
#  | > Max audio length: 124969.0
#  | > Min audio length: 104443.0
#  | > Avg audio length: 115444.8
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#
#  > EVALUATION
#
# warning: audio amplitude out of range, auto clipped.
#  | > Synthesizing test sentences.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
# warning: audio amplitude out of range, auto clipped.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.10616 (+0.00087)
#      | > avg_decoder_loss: 2.40937 (-0.10780)
#      | > avg_postnet_loss: 2.18301 (-0.09575)
#      | > avg_stopnet_loss: 0.12176 (-0.00374)
#      | > avg_ga_loss: 0.00520 (+0.00011)
#      | > avg_loss: 4.74012 (-0.20674)
#      | > avg_align_error: 0.73245 (-0.01148)

# %% [markdown]
# #Generate audio using the fine-tuned model
# This cell generates an audio file using the fine-tuned model and plays the synthesized audio.
# ###Change the model_path and config_path for every fine tuning.
# - The path can be traced referring to the below paths.

# %%
# !tts --model_path /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/best_model.pth \
    --config_path /content/Trainings/LJSpeech/ljspeech-ddc-May-06-2023_05+53PM-0000000/config.json \
    --out_path /content/fine_tuned_generated_audio.wav \
    --text "What were you doing!! I told you to come fast."
# Out:
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:1.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Model's reduction rate `r` is set to: 1
#  > Text: What were you doing!! I told you to come fast.
#  > Text splitted to sentences.
# ['What were you doing!!', 'I told you to come fast.']
#  > Processing time: 3.2137253284454346
#  > Real-time factor: 0.8566567153315019
#  > Saving output to /content/trained_generated_audio.wav

# %%
Audio("/content/fine_tuned_generated_audio.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
